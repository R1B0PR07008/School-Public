# %%
import pandas as pd

x = [1.795378129, 1.793328197, 1.757648913, 1.766314182, 1.800003056, 1.770878436]

df = pd.DataFrame(x, columns=['Values'])

df.std()
# Out:
# Values    0.017789
# dtype: float64
