# %%
import pynance as pn
import matplotlib 
import pandas 
import datetime

# %%
nvidia_ = pn.data.get('NVDA', '2015', '2024')
AMD_ = pn.data.get('AMD', '2015', '2024')
apple_ = pn.data.get('AAPL', '2015', '2024')
intel_ = pn.data.get('INTC', '2015', '2024')
tsmc_ = pn.data.get('TSM', '2015', '2024')
asml_ = pn.data.get('ASML', '2015', '2024')
microsoft_ = pn.data.get('MSFT', '2015', '2024')
amazon_ = pn.data.get('AMZN', '2015', '2024')

print(type(nvidia_))

asml_
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                 Open      High       Low     Close        Volume
# Date
# 2023-12-29  758.0300  760.3500  752.3300  756.9200  5.180060e+05
# 2023-12-28  762.0700  763.0900  757.8100  757.8500  4.679530e+05
# 2023-12-27  760.8200  764.4800  758.3500  764.0300  4.870760e+05
# 2023-12-26  750.1000  765.7950  750.0000  762.6800  5.092420e+05
# 2023-12-22  752.8400  755.8200  749.1050  752.5300  5.973640e+05
# ...              ...       ...       ...       ...           ...
# 2015-01-08   95.1380   97.3030   95.0543   96.5077  5.160170e+05
# 2015-01-07   93.7384   94.6453   93.5224   94.5397  9.161840e+05
# 2015-01-06   95.7671   95.8537   93.8319   94.0012  1.158578e+06
# 2015-01-05   98.7642   99.0310   96.7376   96.8640  7.272069e+05
# 2015-01-02  100.4970  101.1740   99.4422  100.2490  4.240304e+05
#
# [2264 rows x 5 columns]

# %%
nvidia_['Open']
# Out:
# Date
# 2023-12-29    49.810700
# 2023-12-28    49.640700
# 2023-12-27    49.508700
# 2023-12-26    48.965700
# 2023-12-22    49.192700
#                 ...
# 2015-01-08     0.464787
# 2015-01-07     0.464087
# 2015-01-06     0.475793
# 2015-01-05     0.483273
# 2015-01-02     0.483273
# Name: Open, Length: 2264, dtype: float64

# %%
index = []

for i in range(0,2264):
    index.append(i)

nvidia = nvidia_.assign(index=index)

nvidia_.to_csv(path_or_buf='./data/nvidia.csv')
AMD_.to_csv(path_or_buf='./data/amd.csv')
apple_.to_csv(path_or_buf='./data/apple.csv')
intel_.to_csv(path_or_buf='./data/intel.csv')
tsmc_.to_csv(path_or_buf='./data/tsmc.csv')
asml_.to_csv(path_or_buf='./data/asml.csv')
microsoft_.to_csv(path_or_buf='./data/microsoft.csv')
amazon_.to_csv(path_or_buf='./data/amazing.csv')


# here I define an index since I can't get the value of 'date' this index can be used to get the date
# for example: index 0 == most recent date, index 2264 == furthest date

# %%
# function to calculate the date based on an index number

def index_calc(index):
    date_max = datetime.date(2023,12,29)

    delta = datetime.timedelta(days=index)

    new_DATE = date_max - delta

    return new_DATE

# %%
nvidia2 = pandas.read_csv('./data/nvidia.csv')
intel2 = pandas.read_csv('./data/intel.csv')
amd2 = pandas.read_csv('./data/amd.csv')
apple2 = pandas.read_csv('./data/apple.csv')
tsmc2 = pandas.read_csv('./data/tsmc.csv')
asml2 = pandas.read_csv('./data/asml.csv')
microsoft2 = pandas.read_csv('./data/microsoft.csv')
amazing2 = pandas.read_csv('./data/amazing.csv')

asml2['Date'][:10]
# Out:
# 0    2023-12-29
# 1    2023-12-28
# 2    2023-12-27
# 3    2023-12-26
# 4    2023-12-22
# 5    2023-12-21
# 6    2023-12-20
# 7    2023-12-19
# 8    2023-12-18
# 9    2023-12-15
# Name: Date, dtype: object

# %%
def find_date(date:str):
    x = 0
    for i in nvidia2['Date']:
        if i == date:
            return x
        x = x+1

# %%
find_date('2023-12-22')
# Out:
# 4

# %% [markdown]
# finding news

# %%
import requests
import csv
import json

news = 0

def newsFromCNN(): 
    query_params = {
        "q":"nvidia",
        "apiKey":"71849c70a62846ffb1018c530ffb18eb",
        "sortBy":"publishedAt",
        "language":"en"
    }

    main_url = "https://newsapi.org/v2/everything?"

    responce = requests.get(main_url, params=query_params)
    cnn_page = responce.json()

    news = pandas.json_normalize(cnn_page["articles"],
                                 meta=['source', 'author', 'tittle', 'description', 'url', 'urlToImage', 'publishedAt', 'content'])

    return news

# %%
newsFromCNN()
# Out:
#                   author                                              title  \
# 0                 PYMNTS  Temenos Offers On-Site GenAI From Nvidia for B...
# 1    breakingthenews.net  Wall Street mixed at close with Nvidia in lime...
# 2          SmartLake5832  Dell Outlet - Like New - G16 Gaming Laptop (76...
# 3              Sayan Sen  TECH_BARGAINS 11/19: Apple MacBooks, iPhones, ...
# 4            Jeremy Kahn  At Web Summit last week, no sign of an AI slow...
# ..                   ...                                                ...
# 95             Liam Dawe    NVIDIA stable driver 550.135 released for Linux
# 96                 David  Rafay Debuts New Platform Capabilities to Spee...
# 97  Vinamrata Chaturvedi  Super Micro Computer stock soars 30% as it avo...
# 98           Jim Thacker                      5 key features in Blender 4.3
# 99          Sarfraz Khan  NVIDIA Announces Its New AI PC Channel: Compan...
#
#                                           description  \
# 0   Banking software provider Temenos says it has ...
# 1   Major stock exchanges in the United States tra...
# 2   i9, RTX 4070 Dell G16 16&quot; Gaming (7630) f...
# 3   In today's TECH_BARGAINS, we cover some of the...
# 4   The value of AI application companies is deter...
# ..                                                ...
# 95  While NVIDIA continues working on new features...
# 96  Rafay Systems announced new platform advanceme...
# 97  Super Micro Computer stock (SMCI) surged more ...
# 98  Now available: read our pick of the new featur...
# 99  NVIDIA, the current market leader in AI, is no...
#
#                                                   url  \
# 0   https://www.pymnts.com/artificial-intelligence...
# 1               https://biztoc.com/x/76098afc6ba95b2b
# 2   https://slickdeals.net/f/17902128-dell-outlet-...
# 3   https://www.neowin.net/deals/techbargains-1119...
# 4   https://fortune.com/2024/11/19/web-summit-ai-s...
# ..                                                ...
# 95  https://www.gamingonlinux.com/2024/11/nvidia-s...
# 96  https://vmblog.com:443/archive/2024/11/19/rafa...
# 97  https://qz.com/super-micro-auditor-compliance-...
# 98  https://www.cgchannel.com/2024/11/5-key-featur...
# 99  https://wccftech.com/nvidia-announces-its-new-...
#
#                                            urlToImage           publishedAt  \
# 0   https://www.pymnts.com/wp-content/uploads/2024...  2024-11-19T21:01:43Z
# 1      https://biztoc.com/cdn/76098afc6ba95b2b_s.webp  2024-11-19T21:01:18Z
# 2   https://static.slickdealscdn.com/images/sd_sha...  2024-11-19T20:56:42Z
# 3   https://cdn.neowin.com/news/images/uploaded/20...  2024-11-19T20:54:02Z
# 4   https://fortune.com/img-assets/wp-content/uplo...  2024-11-19T20:49:34Z
# ..                                                ...                   ...
# 95  https://www.gamingonlinux.com/uploads/tagline_...  2024-11-19T15:43:23Z
# 96                                               None  2024-11-19T15:42:00Z
# 97  https://i.kinja-img.com/image/upload/c_fill,h_...  2024-11-19T15:41:49Z
# 98                                                     2024-11-19T15:30:47Z
# 99  https://cdn.wccftech.com/wp-content/uploads/20...  2024-11-19T15:30:15Z
#
#                                               content source.id  \
# 0   Banking software provider Temenos says it has ...      None
# 1   Major stock exchanges in the United States tra...      None
# 2   i9, RTX 4070 Dell G16 16" Gaming (7630) for sa...      None
# 3   Western Digital (WD) may have joined Nakamichi...      None
# 4   Hello and welcome to Eye on AI. In this editio...   fortune
# ..                                                ...       ...
# 95  While NVIDIA continues working on new features...      None
# 96  Rafay Systems announced new platform advanceme...      None
# 97  In This Story\r\nSuper Micro Computer stock (S...      None
# 98  Tuesday, November 19th, 2024\r\nPosted by Jim ...      None
# 99  NVIDIA, the current market leader in AI, is no...      None
#
#           source.name
# 0          pymnts.com
# 1          Biztoc.com
# 2      Slickdeals.net
# 3              Neowin
# 4             Fortune
# ..                ...
# 95  Gamingonlinux.com
# 96         Vmblog.com
# 97       Quartz India
# 98      Cgchannel.com
# 99           Wccftech
#
# [100 rows x 9 columns]

# %%
import matplotlib
import matplotlib.pyplot

date = nvidia2["Date"]
close = nvidia2['Close']

matplotlib.pyplot.plot(date, close, label="nvidia")
matplotlib.pyplot.plot(amd2['Date'], amd2['Close'], label="amd")
matplotlib.pyplot.plot(apple2['Date'], apple2['Close'], label="apple")
matplotlib.pyplot.plot(tsmc2['Date'], tsmc2['Close'], label="tsmc")
matplotlib.pyplot.plot(asml2['Date'], asml2['Close'], label="asml")
matplotlib.pyplot.plot(intel2['Date'], intel2['Close'], label="intel")
matplotlib.pyplot.plot(microsoft2['Date'], microsoft2['Close'], label="microsoft")
matplotlib.pyplot.plot(amazing2['Date'], amazing2['Close'], label="amazon")
matplotlib.pyplot.legend()
matplotlib.pyplot.show()

# %%
#save news data as csv

newsFromCNN().to_csv('data/news.csv')

# %%
# daily difference in closing price 
def diffs(DaTa):
    dif : list = []
    x=1
    for i in range(0,len(DaTa)): 
        o = (DaTa[x]*100/DaTa[i])-100
        
        x=x+1

        dif.append(o)

        if x >= 2263:
            x=x-1
    return dif

dif_Nvidia = diffs(nvidia2["Close"].to_list())
dif_amd = diffs(amd2["Close"].to_list())
dif_intel = diffs(intel2["Close"].to_list())
dif_tsmc = diffs(tsmc2["Close"].to_list())
dif_microsoft = diffs(microsoft2["Close"].to_list())
dif_amazon = diffs(amazing2["Close"].to_list())
dif_apple = diffs(apple2["Close"].to_list())
dif_asml = diffs(asml2["Close"].to_list())

# %%
def avg_dif(dif): 
    x =sum(dif)/len(dif)
    return x

avg_dif(dif_apple)
# Out:
# -0.07687076422627175

# %%
date_list = date.to_list()

line = 0.3

matplotlib.pyplot.plot(date, dif_Nvidia, linewidth=line)
matplotlib.pyplot.plot(date, dif_apple, linewidth=line)
matplotlib.pyplot.plot(date, dif_amd, linewidth=line)
matplotlib.pyplot.plot(date, dif_intel, linewidth=line)
matplotlib.pyplot.plot(date, dif_amazon, linewidth=line)
matplotlib.pyplot.plot(date, dif_microsoft, linewidth=line)
matplotlib.pyplot.plot(date, dif_asml, linewidth=line)
matplotlib.pyplot.plot(date, dif_tsmc, linewidth=line)

matplotlib.pyplot.ylabel('Daily difference ($)')
matplotlib.pyplot.xlabel('Time(days)')
matplotlib.pyplot.title('Daily stock price difference (2015-2023)')

matplotlib.pyplot.savefig("output-343.jpg")

# %%
matplotlib.pyplot.bar("Nvidia", avg_dif(dif_Nvidia))
matplotlib.pyplot.bar("Apple", avg_dif(dif_apple))
matplotlib.pyplot.bar("Amd", avg_dif(dif_amd))
matplotlib.pyplot.bar("Intel", avg_dif(dif_intel))
matplotlib.pyplot.bar("Amazon", avg_dif(dif_amazon))
matplotlib.pyplot.bar("Microsoft", avg_dif(dif_microsoft))
matplotlib.pyplot.bar("Asml", avg_dif(dif_asml))
matplotlib.pyplot.bar("Tsmc", avg_dif(dif_tsmc))

matplotlib.pyplot.ylabel('AVG difference ($)')
matplotlib.pyplot.xlabel('Company')
matplotlib.pyplot.title('AVG daily stock price difference (2015-2023)')

matplotlib.pyplot.savefig("output-344.jpg")

# %%
import matplotlib.pyplot as plt
import numpy as np


x = nvidia2['Close']
y = nvidia2['Volume']

plt.scatter(nvidia2['Close'], nvidia2['Volume'], label="Nvidia")

#line of best fit
# Fit a line to the data
m = np.polyfit(x, y, 3)
p = np.poly1d(m)

plt.plot(x, p(y), label="fit")
