# %%
import requests
import pandas
import csv
import json

news = 0

def newsFromCNN(): 
    query_params = {
        "q":"Iphone",
        "apiKey":"71849c70a62846ffb1018c530ffb18eb",
        "sortBy":"publishedAt",
        "language":"en"
    }

    main_url = "https://newsapi.org/v2/everything?"

    responce = requests.get(main_url, params=query_params)
    cnn_page = responce.json()

    with open('news.json', 'w') as f:
        json.dump(cnn_page, f)

        print('successfully wrote to file')

    news = pandas.json_normalize(cnn_page["articles"],
                                 meta=['source', 'author', 'tittle', 'description', 'url', 'urlToImage', 'publishedAt', 'content'])

    return news

newsFromCNN()
# Out:
# successfully wrote to file
#                                                author  \
# 0                                            RP Staff
# 1                                    NYT News Service
# 2                                           Kerry Wan
# 3                                            RP Staff
# 4                                          Jay Peters
# ..                                                ...
# 91                                       John Quintet
# 92                                          Kerry Wan
# 93  Rosa Escandon, Contributor, \n Rosa Escandon, ...
# 94                                    Mike Sorrentino
# 95                                       Austin Blake
#
#                                                 title  \
# 0   [0 Risk] Best Pokémon Go Spoofer Without Crack...
# 1   $3,000 for a used iPhone? In US, if it has Tik...
# 2   One day later with Samsung Galaxy S25 Ultra - ...
# 3   [Prove Guide] Fix iPad Stuck On Restore Screen...
# 4   Apple makes a change to its AI team and plans ...
# ..                                                ...
# 91  Freedom Mobile Sets End Date for Canada-US-Mex...
# 92  Samsung Galaxy S25 Ultra hands-on: One day lat...
# 93      10 Films To Watch If You Liked ‘Emilia Pérez’
# 94  Samsung Galaxy S25's Qi2 Ready Case Is A Small...
# 95            New on Paramount+ Canada: February 2025
#
#                                           description  \
# 0   Cracked games and apps can put your device and...
# 1   Due to the ban on TikTok, users are listing th...
# 2   The lighter and thinner design, upgraded proce...
# 3   Facing an iPad stuck on restore screen issue? ...
# 4   Apple’s Kim Vorrath, who helped get Vision Pro...
# ..                                                ...
# 91  Videotron’s Freedom Mobile has now set an end ...
# 92  The lighter and thinner design, upgraded proce...
# 93  Emilia Pérez was recently nominated for 13 Osc...
# 94  Commentary: We want to see Android phones with...
# 95  Paramount+ Canada announced this morning the n...
#
#                                                   url  \
# 0   https://www.redmondpie.com/0-risk-best-pokemon...
# 1   https://timesofindia.indiatimes.com/world/us/3...
# 2   https://www.zdnet.com/article/samsung-galaxy-s...
# 3   https://www.redmondpie.com/prove-guide-fix-ipa...
# 4   https://www.theverge.com/2025/1/24/24351391/ap...
# ..                                                ...
# 91  https://www.iphoneincanada.ca/2025/01/24/freed...
# 92  https://www.zdnet.com/article/samsung-galaxy-s...
# 93  https://www.forbes.com/sites/rosaescandon/2025...
# 94  https://www.cnet.com/tech/mobile/samsung-galax...
# 95  https://www.iphoneincanada.ca/2025/01/24/new-o...
#
#                                            urlToImage           publishedAt  \
# 0   https://cdn.redmondpie.com/wp-content/uploads/...  2025-01-25T00:33:48Z
# 1   https://static.toiimg.com/thumb/msid-117539576...  2025-01-25T00:32:51Z
# 2   https://www.zdnet.com/a/img/resize/591eee7969a...  2025-01-25T00:29:52Z
# 3   https://cdn.redmondpie.com/wp-content/uploads/...  2025-01-25T00:26:43Z
# 4   https://cdn.vox-cdn.com/thumbor/SLPLACy9HgNc8s...  2025-01-24T23:44:05Z
# ..                                                ...                   ...
# 91  https://cdn.iphoneincanada.ca/wp-content/uploa...  2025-01-24T18:16:51Z
# 92  https://www.zdnet.com/a/img/resize/35602b5c8dc...  2025-01-24T18:15:00Z
# 93  https://imageio.forbes.com/specials-images/ima...  2025-01-24T18:09:09Z
# 94  https://www.cnet.com/a/img/resize/f25d5ba7d3ca...  2025-01-24T18:05:21Z
# 95  https://cdn.iphoneincanada.ca/wp-content/uploa...  2025-01-24T18:05:03Z
#
#                                               content           source.id  \
# 0   Game developers have strict protocols in place...                None
# 1                       10 most beautiful sea animals  the-times-of-india
# 2   Samsung's Big Bad Galaxy phone has arrived, an...                None
# 3   Dealing with an iPad stuck on restore screen c...                None
# 4   Apple makes a change to its AI team and plans ...           the-verge
# ..                                                ...                 ...
# 91  Videotrons Freedom Mobile has now set an end d...                None
# 92  Samsung's Big Bad Galaxy phone has arrived, an...                None
# 93  Adriana Paz, Edgar Ramírez, Selena Gomez, Jacq...                None
# 94  We have been waiting and waiting for more Andr...                None
# 95  Paramount+ Canada announced this morning the n...                None
#
#            source.name
# 0       redmondpie.com
# 1   The Times of India
# 2                ZDNet
# 3       redmondpie.com
# 4            The Verge
# ..                 ...
# 91    iPhone in Canada
# 92               ZDNet
# 93              Forbes
# 94                CNET
# 95    iPhone in Canada
#
# [96 rows x 9 columns]
